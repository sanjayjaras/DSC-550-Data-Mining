# %% [markdown]
# # <center>Data Mining Project: Brain Tumor Detection</center>
# ## <center>Sanjay Jars</center>
# ## <center>DSC 550</center>
# ## <center>Bellevue University</center>

# %% [markdown]
# With every year, the number of patients with a brain tumor is increasing. There are two classes of brain tumors, primary and secondary tumors. Primary tumors have several types; one of the frequently found is a meningioma type. This type of tumors found near the top and outer curve of the brain. Meningioma is slowly growing noncancerous tumors that cause seizures and visual problems. Glioma is an abnormal growth in glial cells present around the neurons in the brain. Pituitary tumors grow in pituitary glands that affect body functions.<br /> It is a very difficult to locate, detect, and select the infected tumor portion in the brain from the MRI (Magnetic resonance images). This tedious and time-consuming task is performed by radiologists and medical field experts. The accuracy of this task is mainly dependent on the experience and expertise of the person performing this task. So, if we use a machine learning model to perform this task, it will help to overcome the shortcomings with the person involved in performing this task. So, I think if we can automate this process of classifying the tumors by using machine learning algorithms it will improve the accuracy of the results and cost due to the expertise required. If we correctly classify the tumors, the specific treatment to that type can be applied. The accurate information about type and location helps in planning the surgical process for its removal.<br /> I will be following an approach involving image preprocessing like segmentation, extraction, and classification. The segmentation will be used to segment and divide the tumor region. The extraction will be used to extract information from the segmented image. Classification will help to compare the extracted information with information from the available dataset. Image pre-processing will be performed to reduce the noise level in the image. For segmentation, I am thinking about using K-means unsupervised algorithm. Then we can use a Support vector machine that can be used to classify the segmented image. Once the model is trained, we can give new images and the model will predict the class for the new image. I time permits I would also like to create a CNN model for prediction. I will be using the brain tumor images dataset from https://figshare.com/articles/brain_tumor_dataset/1512427. This dataset contains 3064 T1-weighted contrast-enhanced images from 233 patients with three kinds of brain tumors. The data is organized in the MATLAB data format (.mat file). Each file stores a struct containing the following fields for an image: cjdata.label: 1 for meningioma, 2 for glioma, 3 for pituitary tumor cjdata.PID: patient ID cjdata.image: image data cjdata.tumorBorder: a vector storing the coordinates of discrete points on tumor border. cjdata.tumorMask: a binary image with 1s indicating tumor region. I am planning to measure the accuracy of classification by testing the model with the test data set. The accuracy of the model can be majored by using the confusion matrix. I will be creating some visualization for images that can compare original images with segmented images.
#
# https://pdfs.semanticscholar.org/b70e/4a5455a4531ca650272474d49d29e5e1da5c.pdf<br />
# https://figshare.com/articles/brain_tumor_dataset/1512427

# %%
import concurrent.futures as cf
import os
import random
import time

import cv2
import h5py as h5  # library to load HDF5 binary file format
import keras
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
import tensorflow
from keras.layers import (
    Activation,
    BatchNormalization,
    Conv2D,
    Dense,
    Flatten,
    Input,
    MaxPool2D,
    ZeroPadding2D,
)
from keras.models import Sequential
from matplotlib import __version__ as mpv
from sklearn.model_selection import train_test_split

print("Using version %s of cv2" % cv2.__version__)
print("Using version %s of pandas" % pd.__version__)
print("Using version %s of matplotlib" % mpv)
print("Using version %s of seaborn" % sns.__version__)
print("Using version %s of sklearn" % sklearn.__version__)
print("Using version %s of numpy" % np.__version__)
print("Using version %s of h5py" % h5.__version__)
print("Using version %s of keras" % keras.__version__)
print("Using version %s of tensorflow" % tensorflow.__version__)
# Out:
# Using version 4.2.0 of cv2
# Using version 1.0.5 of pandas
# Using version 3.2.2 of matplotlib
# Using version 0.10.1 of seaborn
# Using version 0.23.1 of sklearn
# Using version 1.18.5 of numpy
# Using version 2.10.0 of h5py
# Using version 2.4.3 of keras
# Using version 2.2.0 of tensorflow

# %% [markdown]
# ### Configurations

# %%
seed = 13
tensorflow.random.set_seed(seed)
np.random.seed(seed)
random.seed(seed)
folder = "original-mat-files"
target_folder = "converted-images/"
#plt.style.use("seaborn-darkgrid")

# %% [markdown]
# ### Scan Source .mat files

# %%
onlyfiles = [
    os.path.join(folder, f)
    for f in os.listdir(folder)
    if os.path.isfile(os.path.join(folder, f)) and f.endswith(".mat")
]
os.makedirs(target_folder, exist_ok=True)

# %% [markdown]
# ### Utility class to parse the .mat file and read contents

# %%
class MatImage(object):
    patient_id = ""
    image = ""
    label = ""
    tumor_border = ""
    tumor_mask = ""
    file_name = ""

    def __init__(self, file_name, file_path=None):
        path = file_name
        if file_path is not None:
            path = os.path.join(file_path, file_name)
        f = h5.File(path, "a")

        self.file_name = file_name
        self.image = np.mat(f["/cjdata/image"])
        self.patient_id = np.array(f["/cjdata/PID"])
        self.label = np.array(f["/cjdata/label"])
        self.tumor_border = np.mat(f["/cjdata/tumorBorder"])
        self.tumor_mask = np.mat(f["/cjdata/tumorMask"])

    # function to plot image with mask
    def draw_image_with_mask(self):
        ax = sns.heatmap(self.tumor_mask, alpha=0.2)
        ax = sns.heatmap(self.image)
        plt.show()

    # Function to apply medain filter on image for removing noise
    def get_median_filtered_image(self, filter_size=2):
        return ndimage.median_filter(self.image, filter_size)

    def tostring(self):
        result = "Patient Id:"
        for pid in self.patient_id:
            result += str(id) + ","
        result += " label"
        for label in self.label:
            result += str(label) + ","
        result += "File Name:" + self.file_name
        return result

# %% [markdown]
# ### Original images

# %%
plt.rcParams["figure.figsize"] = [20, 8]
fig, axs = plt.subplots(3, 10)
i = 0
for filepath in onlyfiles:
    p1 = MatImage(onlyfiles[i])
    axs[int(i / 10), i % 10].imshow(p1.image)
    i += 1
    if i >= 30:
        break
plt.suptitle("Original image from .mat files")
plt.show()
del p1

# %% [markdown]
# ### Image with mask plotted on top of image

# %%
p1 = MatImage(folder + "/22.mat")
plt.rcParams["figure.figsize"] = [15, 8]
fig, axs = plt.subplots(1, 2)
axs[0].imshow(p1.image)
axs[0].imshow(p1.tumor_mask, alpha=0.1)
axs[0].set(title="Image with mask")
axs[1].imshow(p1.tumor_mask)
axs[1].set(title="Mask")
plt.show()

# %% [markdown]
# ### Read mat files
# ### 1. Use median filter to enhance images
# ### 2. Crop the images to only contain actual brain image and remove extra image parts
# ### 3. Resize all images to 256*256 dimension

# %%
IMG_SIZE = (256, 256)


def crop_image(image_path, IMG_SIZE=(256, 256)):
    # read image
    img = cv2.imread(image_path)
    # resize image to smaller dimensions
    img = cv2.resize(img, dsize=IMG_SIZE, interpolation=cv2.INTER_CUBIC)
    # convert to gray
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    # add some blurring
    gray = cv2.GaussianBlur(gray, (5, 5), 0)

    # threshold the image, then perform a series of erosions +
    # dilations to remove any small regions of noise
    thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
    thresh = cv2.erode(thresh, None, iterations=2)
    thresh = cv2.dilate(thresh, None, iterations=2)

    # find contours in thresholded image, then grab the largest one
    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    c = max(cnts, key=cv2.contourArea)

    # find the extreme points
    extLeft = tuple(c[c[:, :, 0].argmin()][0])
    extRight = tuple(c[c[:, :, 0].argmax()][0])
    extTop = tuple(c[c[:, :, 1].argmin()][0])
    extBot = tuple(c[c[:, :, 1].argmax()][0])

    # add contour on the image
    img_cnt = cv2.drawContours(img.copy(), [c], -1, (0, 255, 255), 4)

    # add extreme points
    img_pnt = cv2.circle(img_cnt.copy(), extLeft, 8, (0, 0, 255), -1)
    img_pnt = cv2.circle(img_pnt, extRight, 8, (0, 255, 0), -1)
    img_pnt = cv2.circle(img_pnt, extTop, 8, (255, 0, 0), -1)
    img_pnt = cv2.circle(img_pnt, extBot, 8, (255, 255, 0), -1)

    # crop
    ADD_PIXELS = 0
    new_img = img[
        extTop[1] - ADD_PIXELS : extBot[1] + ADD_PIXELS,
        extLeft[0] - ADD_PIXELS : extRight[0] + ADD_PIXELS,
    ].copy()
    # resize image to input dimensions after cropping
    new_img = cv2.resize(new_img, dsize=IMG_SIZE, interpolation=cv2.INTER_CUBIC)
    # return gray scale image
    gray = cv2.cvtColor(new_img, cv2.COLOR_RGB2GRAY)
    return gray

# %% [markdown]
# Function to save image as png

# %%
def save_image(image_array, file_path, format="png"):
    fig, ax = plt.subplots()
    im = ax.imshow(image_array)
    plt.imsave(
        file_path, image_array, format=format,
    )
    plt.close(fig)

# %% [markdown]
# Transform files as mentioned above and save them

# %% [markdown]
# def save_filese_as_image(mat_file_path):
#     # read input .mat file
#     mat_image = MatImage(mat_file_path)
#     filename = mat_image.file_name.split("/")[-1].split(".")[0]
#     target_file_path = target_folder + filename + "_" + str(int(mat_image.label[0][0])) + ".png"
#     # save image after applying median filter
#     save_image(mat_image.get_median_filtered_image(), target_file_path)
#     # apply cropping
#     conv_image = crop_image(target_file_path)
#     # save image again
#     save_image(conv_image, target_file_path)
#
# # use multiple cores for above operation
# start_time = time.time()
# with cf.ProcessPoolExecutor() as executor:
#         results = executor.map(save_filese_as_image, onlyfiles)
# print(f"--- {(time.time() - start_time)} seconds for transforming {len(onlyfiles)} files---"  )

# %% [markdown]
# ### Scan all converyed image files

# %%
onlyfiles = [
    os.path.join(target_folder, f)
    for f in os.listdir(target_folder)
    if os.path.isfile(os.path.join(target_folder, f)) and f.endswith(".png")
]

# %% [markdown]
# ### Images after above transformations

# %%
plt.rcParams["figure.figsize"] = [20, 8]
fig, axs = plt.subplots(3, 10)
i = 0
for filepath in onlyfiles:
    img = cv2.imread(filepath)
    axs[int(i / 10), i % 10].imshow(img)
    i += 1
    if i >= 30:
        break
plt.suptitle("Images after transformation is applied")
plt.show()
del img

# %% [markdown]
# ### Function to load all images into numpy arrays with labels

# %%
def load_image(image_path):
    img = cv2.imread(image_path)
    # enable this to remove last dimension 3
    # img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    filename = image_path.split("/")[-1].split(".")[0]
    label = filename.split("_")[-1]
    return img, int(label), filename


def get_data_set(for_cnn=False):
    images = []
    labels = []

    filenames = []
    with cf.ProcessPoolExecutor() as executor:
        results = executor.map(load_image, onlyfiles)

    for result in results:
        if result[0] is not None:
            if result[0].shape[0] != 256 or result[0].shape[1] != 256:
                print("Dropping image as dimensions are not correct", result[2])
            else:
                image = result[0]
                if for_cnn:
                    # images.append(image)
                    if result[1] == 1:
                        labels.append([1, 0, 0])
                    elif result[1] == 2:
                        labels.append([0, 1, 0])
                    else:
                        labels.append([0, 0, 1])
                else:
                    labels.append(result[1])
                #images.append(cv2.cvtColor(image, cv2.COLOR_RGB2GRAY))
                images.append(image)
                filenames.append(result[2])
    output_image = np.empty((len(images), 256, 256, 3))

    for i in range(len(images)):
        output_image[i] = images[i]

    return output_image, np.array(labels)

# %%
i = load_image('converted-images/1000_3.png')
i[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# ### Load all images

# %%
start_time = time.time()
dataset_xc, dataset_yc = get_data_set(for_cnn=True)
print("Shape of dataset-X", dataset_xc.shape)
print("Shape of dataset-Y", dataset_yc.shape)
print(
    f"--- {(time.time() - start_time)} seconds for loading {len(dataset_xc)} files---"
)
# Out:
# Shape of dataset-X (3064, 256, 256, 3)
# Shape of dataset-Y (3064, 3)
# --- 10.91787052154541 seconds for loading 3064 files---

# %% [markdown]
# ### Reshape the dataset to be used with model

# %%
print("dataset_yc:", dataset_yc.shape)
yc = dataset_yc.reshape(len(dataset_yc), -1)
print("yc:", yc.shape)
print("dataset_yc:", dataset_xc.shape)
xc = dataset_xc.reshape(len(dataset_xc), -1)
xc.shape
print("xc:", xc.shape)

# %%
yc = dataset_yc
xc = dataset_xc

# %% [markdown]
# ### Split dataset in testsets and training sets

# %%
train_xc, test_xc, train_yc, test_yc, = train_test_split(
    xc, yc, train_size=0.80, random_state=seed
)
print("Training Set length", len(train_xc))
print("Test Set length", len(test_xc))
# Out:
# Training Set length 2451
# Test Set length 613

# %%
train_xc.shape
# Out:
# (2451, 256, 256, 3)

# %% [markdown]
# Function plot model stats

# %%
def plot_comparison(histories, legends, title):
    fig, axs = plt.subplots(2, 2)
    for history in histories:
        rounds = len(history.history["loss"])
        ax1 = sns.lineplot(
            x=range(1, rounds + 1),
            y=history.history["loss"],
            legend="full",
            ax=axs[0, 0],
        )
        ax1.set(title="loss")
        ax1.legend(legends)
        ax2 = sns.lineplot(
            x=range(1, rounds + 1),
            y=history.history["val_loss"],
            legend="full",
            ax=axs[0, 1],
        )
        ax2.set(title="val_loss")
        ax2.legend(legends)
        ax3 = sns.lineplot(
            x=range(1, rounds + 1),
            y=history.history["accuracy"],
            legend="full",
            ax=axs[1, 0],
        )
        ax3.set(title="accuracy")
        ax3.legend(legends)
        ax4 = sns.lineplot(
            x=range(1, rounds + 1),
            y=history.history["val_accuracy"],
            legend="full",
            ax=axs[1, 1],
        )
        ax4.set(title="val_accuracy")
        ax4.legend(legends)

    plt.suptitle(title)
    plt.show()

# %% [markdown]
# ### Build the model for training

# %%
input_shape = 65536
input_shape = (256 , 256, 3)

from keras.layers import Conv1D,MaxPool2D

def create_keras_model(optimizer="sgd"):
    model = Sequential()
    model.add(Input(input_shape))
    model.add(Conv2D(32, (7, 7), strides = (1, 1)))
    # standardizes the inputs to a layer for each mini-batch.
    model.add(BatchNormalization(axis=1, name="bn0"))
    #model.add(Dense(30))
    model.add(Activation("relu"))
    model.add(MaxPool2D((4, 4)))
    model.add(MaxPool2D((4, 4)))
    model.add(Flatten())
    model.add(Dense(3, activation="softmax"))

    model.compile(
        loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"]
    )

    return model

# %%
histories = []
batches = [30, 50]
for batch_size in batches:
    model = create_keras_model()
    print("\n\n", "*" * 50, "Batch Size:", batch_size, "*" * 50)
    model.summary()
    history = model.fit(
        x=train_xc,
        y=train_yc,
        batch_size=batch_size,
        epochs=10,
        validation_split=0.2,
        verbose=1,
    )
    histories.append(history)
    print(history.history)

plot_comparison(
    histories,
    ["Batch-Size=30", "Batch-Size=50"],
    "Model comparison with Batch size changes",
)
# Out:
#  ************************************************** Batch Size: 30 **************************************************
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 250, 250, 32)      4736
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 250, 250, 32)      1000
# _________________________________________________________________
# activation_2 (Activation)    (None, 250, 250, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 62, 62, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 7200)              0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 21603
# =================================================================
# Total params: 27,339
# Trainable params: 26,839
# Non-trainable params: 500
# _________________________________________________________________
# Epoch 1/10
# 66/66 [==============================] - 16s 247ms/step - loss: 3.5638 - accuracy: 0.3602 - val_loss: 1.1604 - val_accuracy: 0.4847
# Epoch 2/10
# 66/66 [==============================] - 5s 77ms/step - loss: 1.3766 - accuracy: 0.3995 - val_loss: 1.5677 - val_accuracy: 0.2994
# Epoch 3/10
# 66/66 [==============================] - 4s 68ms/step - loss: 1.0517 - accuracy: 0.4806 - val_loss: 0.9640 - val_accuracy: 0.5031
# Epoch 4/10
# 66/66 [==============================] - 4s 67ms/step - loss: 0.9939 - accuracy: 0.5306 - val_loss: 1.6465 - val_accuracy: 0.2994
# Epoch 5/10
# 66/66 [==============================] - 5s 73ms/step - loss: 0.9258 - accuracy: 0.5816 - val_loss: 0.8583 - val_accuracy: 0.6456
# Epoch 6/10
# 66/66 [==============================] - 5s 73ms/step - loss: 0.8120 - accuracy: 0.6592 - val_loss: 1.4125 - val_accuracy: 0.3401
# Epoch 7/10
# 66/66 [==============================] - 4s 66ms/step - loss: 0.7475 - accuracy: 0.6862 - val_loss: 0.7726 - val_accuracy: 0.6436
# Epoch 8/10
# 66/66 [==============================] - 4s 67ms/step - loss: 0.7038 - accuracy: 0.7148 - val_loss: 0.8803 - val_accuracy: 0.6477
# Epoch 9/10
# 66/66 [==============================] - 5s 74ms/step - loss: 0.6588 - accuracy: 0.7367 - val_loss: 0.5946 - val_accuracy: 0.7800
# Epoch 10/10
# 66/66 [==============================] - 5s 71ms/step - loss: 0.6673 - accuracy: 0.7224 - val_loss: 0.6458 - val_accuracy: 0.7251
# {'loss': [3.5637950897216797, 1.3766311407089233, 1.0516504049301147, 0.9938592910766602, 0.9258071780204773, 0.812039852142334, 0.747493326663971, 0.7038367986679077, 0.6587982773780823, 0.6673239469528198], 'accuracy': [0.3602040708065033, 0.39948979020118713, 0.48061224818229675, 0.5306122303009033, 0.581632673740387, 0.6591836810112, 0.6862244606018066, 0.7147959470748901, 0.7367346882820129, 0.722449004650116], 'val_loss': [1.1604080200195312, 1.5676968097686768, 0.964048445224762, 1.646543264389038, 0.8582531809806824, 1.412482500076294, 0.7726453542709351, 0.880340039730072, 0.5946450233459473, 0.6457514762878418], 'val_accuracy': [0.48472505807876587, 0.2993890047073364, 0.5030549764633179, 0.2993890047073364, 0.6456211805343628, 0.34012219309806824, 0.6435845494270325, 0.6476578116416931, 0.7800407409667969, 0.7250509262084961]}
#
#
#  ************************************************** Batch Size: 50 **************************************************
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 250, 250, 32)      4736
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 250, 250, 32)      1000
# _________________________________________________________________
# activation_3 (Activation)    (None, 250, 250, 32)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 21603
# =================================================================
# Total params: 27,339
# Trainable params: 26,839
# Non-trainable params: 500
# _________________________________________________________________

# %%
histories_opt = []
for optimizer in ["adam", "sgd", "rmsprop", "adagrad", "adamax"]:
    print("\n\n", "*" * 50, "Optimizer:", optimizer, "*" * 50)
    model = create_keras_model(optimizer)
    model.summary()
    history = model.fit(
        x=train_xc,
        y=train_yc,
        batch_size=30,
        epochs=10,
        validation_split=0.2,
        verbose=1,
    )
    print(history.history)
    histories_opt.append(history)
plot_comparison(
    histories_opt,
    ["adam", "sgd", "rmsprop", "adagrad", "adamax"],
    "Model comparison with Optimizers",
)
# Out:
#  ************************************************** Optimizer: adam **************************************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bn0 (BatchNormalization)     (None, 65536)             262144
# _________________________________________________________________
# dense (Dense)                (None, 1000)              65537000
# _________________________________________________________________
# activation (Activation)      (None, 1000)              0
# _________________________________________________________________
# flatten (Flatten)            (None, 1000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 3003
# =================================================================
# Total params: 65,802,147
# Trainable params: 65,671,075
# Non-trainable params: 131,072
# _________________________________________________________________
# Epoch 1/10
# 66/66 [==============================] - 2s 37ms/step - loss: 23.7346 - accuracy: 0.7332 - val_loss: 566.7789 - val_accuracy: 0.3218
# Epoch 2/10
# 66/66 [==============================] - 2s 27ms/step - loss: 6.3971 - accuracy: 0.8842 - val_loss: 87.1111 - val_accuracy: 0.4338
# Epoch 3/10
# 66/66 [==============================] - 2s 27ms/step - loss: 2.9999 - accuracy: 0.9184 - val_loss: 26.4996 - val_accuracy: 0.5825
# Epoch 4/10
# 66/66 [==============================] - 2s 25ms/step - loss: 1.6012 - accuracy: 0.9439 - val_loss: 6.7698 - val_accuracy: 0.8248
# Epoch 5/10
# 66/66 [==============================] - 2s 25ms/step - loss: 0.9701 - accuracy: 0.9684 - val_loss: 6.1721 - val_accuracy: 0.8269
# Epoch 6/10
# 66/66 [==============================] - 2s 26ms/step - loss: 1.1658 - accuracy: 0.9612 - val_loss: 7.6802 - val_accuracy: 0.8676
# Epoch 7/10
# 66/66 [==============================] - 2s 26ms/step - loss: 1.0586 - accuracy: 0.9617 - val_loss: 6.5500 - val_accuracy: 0.8534
# Epoch 8/10
# 66/66 [==============================] - 2s 26ms/step - loss: 0.6153 - accuracy: 0.9735 - val_loss: 6.3896 - val_accuracy: 0.8676
# Epoch 9/10
# 66/66 [==============================] - 2s 25ms/step - loss: 0.9583 - accuracy: 0.9684 - val_loss: 8.1625 - val_accuracy: 0.8758
# Epoch 10/10
# 66/66 [==============================] - 2s 26ms/step - loss: 0.9710 - accuracy: 0.9673 - val_loss: 9.0150 - val_accuracy: 0.8513
# {'loss': [23.734588623046875, 6.397116661071777, 2.9998795986175537, 1.6011677980422974, 0.9700985550880432, 1.1657650470733643, 1.0586377382278442, 0.6152874231338501, 0.9582622051239014, 0.9709855914115906], 'accuracy': [0.7331632375717163, 0.8841836452484131, 0.918367326259613, 0.9438775777816772, 0.968367338180542, 0.9612244963645935, 0.9617347121238708, 0.9734693765640259, 0.968367338180542, 0.9673469662666321], 'val_loss': [566.7788696289062, 87.11112213134766, 26.49955940246582, 6.769847393035889, 6.172121524810791, 7.68017053604126, 6.550013542175293, 6.389552593231201, 8.16248607635498, 9.014986991882324], 'val_accuracy': [0.32179227471351624, 0.4338085651397705, 0.5824847221374512, 0.8248472213745117, 0.8268839120864868, 0.867617130279541, 0.8533604741096497, 0.867617130279541, 0.8757637739181519, 0.8513238430023193]}
#
#
#  ************************************************** Optimizer: sgd **************************************************
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bn0 (BatchNormalization)     (None, 65536)             262144
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              65537000
# _________________________________________________________________
# activation_1 (Activation)    (None, 1000)              0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1000)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 3003
# =================================================================
# Total params: 65,802,147
# Trainable params: 65,671,075
# Non-trainable params: 131,072
# _________________________________________________________________
# Epoch 1/10
# 66/66 [==============================] - 2s 37ms/step - loss: 1.4242 - accuracy: 0.7469 - val_loss: 19.1077 - val_accuracy: 0.4644
# Epoch 2/10
# 66/66 [==============================] - 2s 23ms/step - loss: 0.2365 - accuracy: 0.9342 - val_loss: 1.8641 - val_accuracy: 0.6334
# Epoch 3/10
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0486 - accuracy: 0.9816 - val_loss: 1.3347 - val_accuracy: 0.6578
# Epoch 4/10
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0213 - accuracy: 0.9944 - val_loss: 1.5719 - val_accuracy: 0.7006
# Epoch 5/10
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0281 - accuracy: 0.9908 - val_loss: 0.5991 - val_accuracy: 0.8513
# Epoch 6/10
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.6716 - val_accuracy: 0.8676
# Epoch 7/10
# 66/66 [==============================] - 1s 21ms/step - loss: 0.0119 - accuracy: 0.9980 - val_loss: 0.4981 - val_accuracy: 0.8880
# Epoch 8/10
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4961 - val_accuracy: 0.8941
# Epoch 9/10
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.4971 - val_accuracy: 0.8961
# Epoch 10/10
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4782 - val_accuracy: 0.9002
# {'loss': [1.4242173433303833, 0.23646573722362518, 0.04858147352933884, 0.021318277344107628, 0.02811574935913086, 0.010865037329494953, 0.011925889179110527, 0.005068820435553789, 0.004222916439175606, 0.0036122892051935196], 'accuracy': [0.7469387650489807, 0.934183657169342, 0.981632649898529, 0.9943877458572388, 0.9908163547515869, 0.9969387650489807, 0.9979591965675354, 1.0, 0.9989795684814453, 1.0], 'val_loss': [19.10767364501953, 1.8640938997268677, 1.334687352180481, 1.571873664855957, 0.5991348624229431, 0.6715769171714783, 0.49807271361351013, 0.49609434604644775, 0.4971497654914856, 0.47821640968322754], 'val_accuracy': [0.46435844898223877, 0.6334012150764465, 0.657841145992279, 0.7006109952926636, 0.8513238430023193, 0.867617130279541, 0.8879836797714233, 0.8940936923027039, 0.8961303234100342, 0.9002036452293396]}
#
#
#  ************************************************** Optimizer: rmsprop **************************************************
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bn0 (BatchNormalization)     (None, 65536)             262144
# _________________________________________________________________
# dense_4 (Dense)              (None, 1000)              65537000
# _________________________________________________________________
# activation_2 (Activation)    (None, 1000)              0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1000)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 3003
# =================================================================
# Total params: 65,802,147
# Trainable params: 65,671,075
# Non-trainable params: 131,072
# _________________________________________________________________
# Epoch 1/10
# 66/66 [==============================] - 3s 40ms/step - loss: 31.9515 - accuracy: 0.7352 - val_loss: 213.6736 - val_accuracy: 0.4236
# Epoch 2/10
# 66/66 [==============================] - 2s 36ms/step - loss: 8.6046 - accuracy: 0.8694 - val_loss: 140.4908 - val_accuracy: 0.3259
# Epoch 3/10
# 66/66 [==============================] - 2s 37ms/step - loss: 5.1357 - accuracy: 0.8883 - val_loss: 51.2542 - val_accuracy: 0.3747
# Epoch 4/10
# 66/66 [==============================] - 2s 36ms/step - loss: 4.3034 - accuracy: 0.9107 - val_loss: 20.1358 - val_accuracy: 0.6456
# Epoch 5/10
# 66/66 [==============================] - 2s 37ms/step - loss: 2.4034 - accuracy: 0.9316 - val_loss: 10.8679 - val_accuracy: 0.8126
# Epoch 6/10
# 66/66 [==============================] - 3s 38ms/step - loss: 1.9340 - accuracy: 0.9474 - val_loss: 14.2166 - val_accuracy: 0.8065
# Epoch 7/10
# 66/66 [==============================] - 2s 37ms/step - loss: 2.8142 - accuracy: 0.9551 - val_loss: 11.0132 - val_accuracy: 0.8534
# Epoch 8/10
# 66/66 [==============================] - 2s 38ms/step - loss: 1.3505 - accuracy: 0.9612 - val_loss: 11.2332 - val_accuracy: 0.8452
# Epoch 9/10
# 66/66 [==============================] - 2s 37ms/step - loss: 1.2051 - accuracy: 0.9684 - val_loss: 9.1785 - val_accuracy: 0.8737
# Epoch 10/10
# 66/66 [==============================] - 2s 36ms/step - loss: 1.7737 - accuracy: 0.9653 - val_loss: 14.5186 - val_accuracy: 0.8126
# {'loss': [31.951515197753906, 8.604646682739258, 5.13565731048584, 4.303427219390869, 2.4034392833709717, 1.9340310096740723, 2.8142194747924805, 1.3505269289016724, 1.2050772905349731, 1.7736608982086182], 'accuracy': [0.7352041006088257, 0.8693877458572388, 0.8882653117179871, 0.9107142686843872, 0.9316326379776001, 0.9474489688873291, 0.9551020264625549, 0.9612244963645935, 0.968367338180542, 0.9653061032295227], 'val_loss': [213.67361450195312, 140.49081420898438, 51.25421905517578, 20.135766983032227, 10.86786937713623, 14.216553688049316, 11.013166427612305, 11.233195304870605, 9.178547859191895, 14.518611907958984], 'val_accuracy': [0.42362526059150696, 0.32586556673049927, 0.3747454285621643, 0.6456211805343628, 0.8126273155212402, 0.8065173029899597, 0.8533604741096497, 0.8452138304710388, 0.8737270832061768, 0.8126273155212402]}
#
#
#  ************************************************** Optimizer: adagrad **************************************************
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bn0 (BatchNormalization)     (None, 65536)             262144
# _________________________________________________________________
# dense_6 (Dense)              (None, 1000)              65537000
# _________________________________________________________________
# activation_3 (Activation)    (None, 1000)              0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1000)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 3003
# =================================================================
# Total params: 65,802,147
# Trainable params: 65,671,075
# Non-trainable params: 131,072
# _________________________________________________________________
# Epoch 1/10
# 66/66 [==============================] - 2s 31ms/step - loss: 9.4161 - accuracy: 0.7551 - val_loss: 28.4911 - val_accuracy: 0.5214
# Epoch 2/10
# 66/66 [==============================] - 2s 25ms/step - loss: 1.3561 - accuracy: 0.9168 - val_loss: 16.2245 - val_accuracy: 0.6762
# Epoch 3/10
# 66/66 [==============================] - 2s 25ms/step - loss: 0.4292 - accuracy: 0.9571 - val_loss: 6.5811 - val_accuracy: 0.7088
# Epoch 4/10
# 66/66 [==============================] - 2s 25ms/step - loss: 0.1560 - accuracy: 0.9816 - val_loss: 3.7729 - val_accuracy: 0.8065
# Epoch 5/10
# 66/66 [==============================] - 2s 25ms/step - loss: 0.1230 - accuracy: 0.9847 - val_loss: 3.2499 - val_accuracy: 0.8493
# Epoch 6/10
# 66/66 [==============================] - 2s 24ms/step - loss: 0.0706 - accuracy: 0.9893 - val_loss: 2.5159 - val_accuracy: 0.8737
# Epoch 7/10
# 66/66 [==============================] - 2s 25ms/step - loss: 0.0618 - accuracy: 0.9939 - val_loss: 2.4352 - val_accuracy: 0.8859
# Epoch 8/10
# 66/66 [==============================] - 2s 24ms/step - loss: 0.0388 - accuracy: 0.9929 - val_loss: 2.6634 - val_accuracy: 0.8656
# Epoch 9/10
# 66/66 [==============================] - 2s 25ms/step - loss: 0.0526 - accuracy: 0.9913 - val_loss: 2.6400 - val_accuracy: 0.8574
# Epoch 10/10
# 66/66 [==============================] - 2s 24ms/step - loss: 0.0336 - accuracy: 0.9923 - val_loss: 2.6210 - val_accuracy: 0.8697
# {'loss': [9.416116714477539, 1.3561204671859741, 0.42919987440109253, 0.15596359968185425, 0.12302011996507645, 0.0706479623913765, 0.06176513433456421, 0.038823794573545456, 0.05257923901081085, 0.03363153710961342], 'accuracy': [0.7551020383834839, 0.9168367385864258, 0.9571428298950195, 0.981632649898529, 0.9846938848495483, 0.9892857074737549, 0.9938775300979614, 0.9928571581840515, 0.9913265109062195, 0.9923469424247742], 'val_loss': [28.49113655090332, 16.22447395324707, 6.581142902374268, 3.7728981971740723, 3.2498884201049805, 2.5159175395965576, 2.435183048248291, 2.6633713245391846, 2.6399972438812256, 2.621006965637207], 'val_accuracy': [0.5213849544525146, 0.676171064376831, 0.7087576389312744, 0.8065173029899597, 0.8492871522903442, 0.8737270832061768, 0.885947048664093, 0.8655804395675659, 0.8574337959289551, 0.8696537613868713]}
#
#
#  ************************************************** Optimizer: adamax **************************************************
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bn0 (BatchNormalization)     (None, 65536)             262144
# _________________________________________________________________
# dense_8 (Dense)              (None, 1000)              65537000
# _________________________________________________________________
# activation_4 (Activation)    (None, 1000)              0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1000)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 3003
# =================================================================
# Total params: 65,802,147
# Trainable params: 65,671,075
# Non-trainable params: 131,072
# _________________________________________________________________
# Epoch 1/10
# 66/66 [==============================] - 2s 31ms/step - loss: 17.3941 - accuracy: 0.7500 - val_loss: 268.3261 - val_accuracy: 0.3605
# Epoch 2/10
# 66/66 [==============================] - 2s 27ms/step - loss: 3.4014 - accuracy: 0.8990 - val_loss: 51.4607 - val_accuracy: 0.5092
# Epoch 3/10
# 66/66 [==============================] - 2s 27ms/step - loss: 1.7725 - accuracy: 0.9357 - val_loss: 14.6634 - val_accuracy: 0.6741
# Epoch 4/10
# 66/66 [==============================] - 2s 27ms/step - loss: 0.9102 - accuracy: 0.9628 - val_loss: 6.7141 - val_accuracy: 0.8187
# Epoch 5/10
# 66/66 [==============================] - 2s 27ms/step - loss: 0.6093 - accuracy: 0.9755 - val_loss: 6.2116 - val_accuracy: 0.8534
# Epoch 6/10
# 66/66 [==============================] - 2s 28ms/step - loss: 0.2295 - accuracy: 0.9821 - val_loss: 5.9218 - val_accuracy: 0.8534
# Epoch 7/10
# 66/66 [==============================] - 2s 26ms/step - loss: 0.5527 - accuracy: 0.9770 - val_loss: 4.8789 - val_accuracy: 0.8737
# Epoch 8/10
# 66/66 [==============================] - 2s 26ms/step - loss: 0.2675 - accuracy: 0.9883 - val_loss: 5.3824 - val_accuracy: 0.8839
# Epoch 9/10
# 66/66 [==============================] - 2s 27ms/step - loss: 0.2696 - accuracy: 0.9852 - val_loss: 6.0243 - val_accuracy: 0.8758
# Epoch 10/10
# 66/66 [==============================] - 2s 26ms/step - loss: 0.2337 - accuracy: 0.9852 - val_loss: 4.8139 - val_accuracy: 0.8758
# {'loss': [17.39413833618164, 3.401365280151367, 1.772519588470459, 0.9102481603622437, 0.6092995405197144, 0.22948695719242096, 0.5526912808418274, 0.26747560501098633, 0.2695658504962921, 0.23372213542461395], 'accuracy': [0.75, 0.8989796042442322, 0.9357143044471741, 0.9627550840377808, 0.9755101799964905, 0.9821428656578064, 0.9770408272743225, 0.988265335559845, 0.9852041006088257, 0.9852041006088257], 'val_loss': [268.32611083984375, 51.46073532104492, 14.663389205932617, 6.714105129241943, 6.211550235748291, 5.921782493591309, 4.878870964050293, 5.382442951202393, 6.024275302886963, 4.813919544219971], 'val_accuracy': [0.36048880219459534, 0.5091649889945984, 0.6741344332695007, 0.818737268447876, 0.8533604741096497, 0.8533604741096497, 0.8737270832061768, 0.8839103579521179, 0.8757637739181519, 0.8757637739181519]}

# %% [markdown]
# ### From above plots I concluded that model with sgd optimizer and batch size 30 is performing well.

# %%
model = create_keras_model("sgd")
model.summary()
history = model.fit(
    x=train_xc, y=train_yc, batch_size=30, epochs=25, validation_split=0.2, verbose=1,
)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bn0 (BatchNormalization)     (None, 65536)             262144
# _________________________________________________________________
# dense_10 (Dense)             (None, 1000)              65537000
# _________________________________________________________________
# activation_5 (Activation)    (None, 1000)              0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1000)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 3003
# =================================================================
# Total params: 65,802,147
# Trainable params: 65,671,075
# Non-trainable params: 131,072
# _________________________________________________________________
# Epoch 1/25
# 66/66 [==============================] - 3s 39ms/step - loss: 1.4655 - accuracy: 0.7474 - val_loss: 17.2221 - val_accuracy: 0.4399
# Epoch 2/25
# 66/66 [==============================] - 2s 26ms/step - loss: 0.2273 - accuracy: 0.9347 - val_loss: 2.6907 - val_accuracy: 0.5071
# Epoch 3/25
# 66/66 [==============================] - 1s 21ms/step - loss: 0.0738 - accuracy: 0.9750 - val_loss: 1.0457 - val_accuracy: 0.7108
# Epoch 4/25
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0216 - accuracy: 0.9939 - val_loss: 0.6129 - val_accuracy: 0.8208
# Epoch 5/25
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0134 - accuracy: 0.9985 - val_loss: 0.4493 - val_accuracy: 0.8717
# Epoch 6/25
# 66/66 [==============================] - 1s 23ms/step - loss: 0.0099 - accuracy: 0.9980 - val_loss: 0.4901 - val_accuracy: 0.8839
# Epoch 7/25
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0051 - accuracy: 0.9995 - val_loss: 0.4765 - val_accuracy: 0.8900
# Epoch 8/25
# 66/66 [==============================] - 1s 21ms/step - loss: 0.0104 - accuracy: 0.9980 - val_loss: 0.4897 - val_accuracy: 0.8921
# Epoch 9/25
# 66/66 [==============================] - 1s 21ms/step - loss: 0.0059 - accuracy: 0.9990 - val_loss: 0.4859 - val_accuracy: 0.8859
# Epoch 10/25
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0066 - accuracy: 0.9985 - val_loss: 0.4658 - val_accuracy: 0.8921
# Epoch 11/25
# 66/66 [==============================] - 1s 21ms/step - loss: 0.0058 - accuracy: 0.9995 - val_loss: 0.4686 - val_accuracy: 0.8982
# Epoch 12/25
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.4699 - val_accuracy: 0.8961
# Epoch 13/25
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.4927 - val_accuracy: 0.8900
# Epoch 14/25
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.5775 - val_accuracy: 0.8697
# Epoch 15/25
# 66/66 [==============================] - 1s 21ms/step - loss: 0.0037 - accuracy: 0.9995 - val_loss: 0.5098 - val_accuracy: 0.8839
# Epoch 16/25
# 66/66 [==============================] - 1s 21ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4989 - val_accuracy: 0.8839
# Epoch 17/25
# 66/66 [==============================] - 1s 21ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4927 - val_accuracy: 0.8880
# Epoch 18/25
# 66/66 [==============================] - 1s 21ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 0.5166 - val_accuracy: 0.8778
# Epoch 19/25
# 66/66 [==============================] - 1s 21ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5152 - val_accuracy: 0.8798
# Epoch 20/25
# 66/66 [==============================] - 1s 21ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4930 - val_accuracy: 0.8859
# Epoch 21/25
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4829 - val_accuracy: 0.8921
# Epoch 22/25
# 66/66 [==============================] - 1s 21ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.4911 - val_accuracy: 0.8941
# Epoch 23/25
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4928 - val_accuracy: 0.8900
# Epoch 24/25
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4783 - val_accuracy: 0.8961
# Epoch 25/25
# 66/66 [==============================] - 1s 21ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4760 - val_accuracy: 0.8941

# %% [markdown]
# Final trained model has validation accuracy of approximatley 89% and loss is around 0.47

# %%
result = model.evaluate(test_xc, test_yc, batch_size=30)
# Out:
# 21/21 [==============================] - 0s 8ms/step - loss: 0.3859 - accuracy: 0.9005

# %% [markdown]
# ### Test Data also shows affroximatly 89% Accuracy and loss 0.38

# %%
print(result)
# Out:
# [0.38590100407600403, 0.9004893898963928]

# %%
predictions = model.predict(test_xc)
y_predicted = predictions.argmax(axis=-1)
# print(y_predicted)
y = test_yc[:].argmax(axis=-1)
# print(y)
total_match = 0
for i in range(len(y_predicted)):
    print("Observed=%s, Predicted=%s" % (y_predicted[i], y[i]))
    if y_predicted[i] == y[i]:
        total_match += 1
accuracy = total_match / len(y_predicted)

print("Calculated Accuracy:", accuracy * 100)
# Out:
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=2, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=0, Predicted=0
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=0, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=0
# Observed=0, Predicted=0
# Observed=0, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=0
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=0
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=0, Predicted=0
# Observed=0, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=0, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=0, Predicted=0
# Observed=1, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=0
# Observed=0, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=0
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=0, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=0
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=0, Predicted=0
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=0
# Observed=0, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=0, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=2
# Observed=1, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=0
# Observed=1, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=0
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=0
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=0
# Observed=2, Predicted=2
# Observed=0, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=0, Predicted=0
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=2
# Observed=2, Predicted=2
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=2, Predicted=2
# Observed=2, Predicted=0
# Observed=1, Predicted=1
# Observed=1, Predicted=1
# Observed=0, Predicted=0
# Observed=2, Predicted=2
# Observed=1, Predicted=0
# Calculated Accuracy: 90.0489396411093
